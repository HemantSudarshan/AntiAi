# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv("/content/drive/MyDrive/True.csv")

# %%
fake = pd.read_csv("/content/drive/MyDrive/Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1)                             #Reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 17524  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 19539  Abdul Razak Ali Artan, a Somalian refugee came...      0
# 19993  Did Hillary forget about her  deplorable  supp...      0
# 10696  MSNBC host Thomas Roberts on Sunday was specul...      0
# 10038  WASHINGTON (Reuters) - Republican presidential...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  17524  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 1  19539  Abdul Razak Ali Artan, a Somalian refugee came...      0
# 2  19993  Did Hillary forget about her  deplorable  supp...      0
# 3  10696  MSNBC host Thomas Roberts on Sunday was specul...      0
# 4  10038  WASHINGTON (Reuters) - Republican presidential...      1

# %%
news.drop(['index'],axis=1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 1  Abdul Razak Ali Artan, a Somalian refugee came...      0
# 2  Did Hillary forget about her  deplorable  supp...      0
# 3  MSNBC host Thomas Roberts on Sunday was specul...      0
# 4  WASHINGTON (Reuters) - Republican presidential...      1

# %%
import re

# %%
def wordopt(text):
  #Convert into lowercase
  text = text.lower()

  #Remove URLs
  text = re.sub(r'https?://\S+|www.\S+','',text)

   # Remove HTML tags
  text = re.sub(r'<.*?>', '', text)

   # Remove punctuation
  text = re.sub(r'[^\w\s]', '', text)

   # Remove digits
  text = re.sub(r'\d', '', text)

   # Remove newline characters
  text = re.sub(r'\n', ' ',text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        washington reuters  us president donald trump ...
# 1        abdul razak ali artan a somalian refugee came ...
# 2        did hillary forget about her  deplorable  supp...
# 3        msnbc host thomas roberts on sunday was specul...
# 4        washington reuters  republican presidential fr...
#                                ...
# 44893    attendees at the  conservative political actio...
# 44894    the washington post reported the patriarchs of...
# 44895    washington reuters  former fbi director james ...
# 44896    it gets more outrageous by the day for the tru...
# 44897     funny how secrets travel i d start to believe...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        washington reuters  us president donald trump ...
# 1        abdul razak ali artan a somalian refugee came ...
# 2        did hillary forget about her  deplorable  supp...
# 3        msnbc host thomas roberts on sunday was specul...
# 4        washington reuters  republican presidential fr...
#                                ...
# 44893    attendees at the  conservative political actio...
# 44894    the washington post reported the patriarchs of...
# 44895    washington reuters  former fbi director james ...
# 44896    it gets more outrageous by the day for the tru...
# 44897     funny how secrets travel i d start to believe...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    0
# 44895    1
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x175036 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6477038 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x175036 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2703995 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Initialize Logistic Regression model
LR = LogisticRegression()

# %%
# Train the model
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions
pred_lr = LR.predict(xv_test)

# %%
# Calculate accuracy
accuracy = LR.score(xv_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9876763177431329

# %%
# Print classification report
print(classification_report(y_test, pred_lr))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
# Initialize Decision Tree Classifier model
DTC = DecisionTreeClassifier()

# %%
# Train the model
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions
pred_dtc = DTC.predict(xv_test)

# %%
# Calculate accuracy
accuracy = DTC.score(xv_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9952487008166295

# %%
# Print classification report
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7048
#            1       0.99      1.00      1.00      6422
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize Random Forest Classifier model
rfc = RandomForestClassifier()

# %%
# Train the model
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions
pred_rfc = rfc.predict(xv_test)

# %%
# Calculate accuracy
accuracy = rfc.score(xv_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9898292501855976

# %%
# Print classification report
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7048
#            1       0.99      0.99      0.99      6422
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Initialize Gradient Boosting Classifier model
gbc = GradientBoostingClassifier()

# %%
# Train the model
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Make predictions
pred_gbc = gbc.predict(xv_test)

# %%
# Calculate accuracy
accuracy = gbc.score(xv_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9943578322197476

# %%
# Print classification report
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      7048
#            1       0.99      1.00      0.99      6422
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
def output_label(n):
    if n == 0:  # corrected comparison operator
        return "It is a Fake News"
    elif n == 1:  # corrected comparison operator
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]}  # Corrected syntax for defining dictionary
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)  # Assuming 'vectorization' is your vectorizer object
    pred_lr = LR.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0]))

# %%
news_article = str(input())
# Out:
# WASHINGTON (Reuters) - The head of a conservative Republican faction in the U.S. Congress, who voted...

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: It is a Genuine News \nGBC Prediction: It is a Genuine News \nRFC Prediction: It is a Genuine News'

# %%
news_article = str(input())
# Out:
# ROURKELA: A 42-year-old man was killed by his friend for all ..  Read more at: http://timesofindia.indiatimes.com/articleshow/107788768.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: It is a Fake News \nGBC Prediction: It is a Fake News \nRFC Prediction: It is a Fake News'
